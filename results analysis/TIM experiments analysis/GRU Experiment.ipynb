# %%
import os
import numpy as np
import pandas as pd
import sys
sys.path.append("/Users/jonathanzha/Desktop/AttenPASOH")
from utils.util import eval_metrix  # Assuming this function exists and is correctly implemented

# %%
# Define the path to the new experiment
experiments_path_gru = "/Users/jonathanzha/Desktop/AttenPASOH/results of reviewer/XJTU(GRU) results"

# add 0-0 to 5-5 to the path, iterate from /Users/jonathanzha/Desktop/AttenPASOH/results of reviewer/XJTU(GRU) results/0-0 to /Users/jonathanzha/Desktop/AttenPASOH/results of reviewer/XJTU(GRU) results/5-5
experiments_path_grus = [os.path.join(experiments_path_gru, f"{i}-{i}") for i in range(6)]

experiments = [f"Experiment{i+1}" for i in range(10)]

def calculate_metrics(true_label_path, pred_label_path):
    # Load true and predicted labels
    true_label = np.load(true_label_path)
    pred_label = np.load(pred_label_path)
    
    # Calculate metrics using the eval_matrix function
    mse, mae, mape, rmse, r2, l1, l2 = eval_metrix(true_label, pred_label)
    
    return mse, mae, mape, rmse, r2, l1, l2

# Loop over each experiment
for experiments_path_gru in experiments_path_grus:
    # Initialize lists to store metrics for each experiment
    mse_list, mae_list, mape_list, rmse_list, r2_list, l1_list, l2_list = [], [], [], [], [], [], []

    for experiment in experiments:
        true_label_path = os.path.join(experiments_path_gru, experiment, 'true_label.npy')
        pred_label_path = os.path.join(experiments_path_gru, experiment, 'pred_label.npy')
        
        # Calculate metrics for the current experiment
        metrics = calculate_metrics(true_label_path, pred_label_path)
        
        mse, mae, mape, rmse, r2, l1, l2 = metrics
        mse_list.append(mse)
        mae_list.append(mae)
        mape_list.append(mape)
        rmse_list.append(rmse)
        r2_list.append(r2)
        l1_list.append(l1)
        l2_list.append(l2)

    # Create a DataFrame to store the metrics
    metrics_df = pd.DataFrame({
        'Experiment': experiments,
        'MSE': mse_list,
        'MAE': mae_list,
        'MAPE': mape_list,
        'RMSE': rmse_list,
        'R^2': r2_list,
        'L1 Error': l1_list,
        'L2 Error': l2_list
    })

    # Calculate the mean values across all numeric columns (excluding 'Experiment')
    mean_values = metrics_df.drop(columns=['Experiment']).mean(axis=0)

    # Append the mean values to the DataFrame
    mean_values_df = pd.DataFrame(mean_values).transpose()
    mean_values_df['Experiment'] = 'Mean'
    metrics_df = pd.concat([metrics_df, mean_values_df], ignore_index=True)

    # Print the results
    print(metrics_df)

    # Save the results to a CSV file
    output_csv_path = os.path.join(experiments_path_gru, 'metrics_summary.csv')
    metrics_df.to_csv(output_csv_path, index=False)
    print(f"Metrics summary saved to {output_csv_path}")
# Out:
#       Experiment       MSE       MAE      MAPE      RMSE       R^2  L1 Error  \
# 0    Experiment1  0.009618  0.010427  0.000154  0.012407  0.936686  0.010281
# 1    Experiment2  0.011026  0.011941  0.000197  0.014046  0.918851  0.011787
# 2    Experiment3  0.005620  0.006170  0.000084  0.009155  0.965525  0.006008
# 3    Experiment4  0.005009  0.005453  0.000076  0.008709  0.968802  0.005354
# 4    Experiment5  0.007371  0.008101  0.000106  0.010313  0.956253  0.007880
# 5    Experiment6  0.009747  0.010565  0.000154  0.012422  0.936525  0.010419
# 6    Experiment7  0.004687  0.005186  0.000079  0.008869  0.967643  0.005010
# 7    Experiment8  0.006168  0.006818  0.000096  0.009820  0.960338  0.006593
# 8    Experiment9  0.007546  0.008250  0.000114  0.010655  0.953303  0.008066
# 9   Experiment10  0.006271  0.006879  0.000092  0.009617  0.961959  0.006703
# 10          Mean  0.007306  0.007979  0.000115  0.010601  0.952589  0.007810
#
#     L2 Error
# 0   0.013244
# 1   0.014994
# 2   0.009773
# 3   0.009297
# 4   0.011009
# 5   0.013261
# 6   0.009468
# 7   0.010482
# 8   0.011374
# 9   0.010266
# 10  0.011317
# Metrics summary saved to /Users/jonathanzha/Desktop/AttenPASOH/results of reviewer/XJTU(GRU) results/0-0/metrics_summary.csv
#       Experiment       MSE       MAE      MAPE      RMSE       R^2  L1 Error  \
# 0    Experiment1  0.010329  0.011010  0.000177  0.013320  0.864863  0.011009
# 1    Experiment2  0.009788  0.010431  0.000166  0.012873  0.873768  0.010432
# 2    Experiment3  0.011636  0.012394  0.000205  0.014332  0.843533  0.012403
# 3    Experiment4  0.011542  0.012356  0.000204  0.014270  0.844884  0.012302
# 4    Experiment5  0.011031  0.011760  0.000186  0.013641  0.858272  0.011757
# 5    Experiment6  0.010502  0.011167  0.000187  0.013657  0.857931  0.011194
# 6    Experiment7  0.011412  0.012170  0.000204  0.014279  0.844690  0.012163
# 7    Experiment8  0.011654  0.012481  0.000205  0.014315  0.843914  0.012421
# 8    Experiment9  0.010938  0.011725  0.000188  0.013709  0.856847  0.011659
# 9   Experiment10  0.011330  0.012129  0.000201  0.014170  0.847066  0.012077
# 10          Mean  0.011016  0.011762  0.000192  0.013857  0.853577  0.011742
#
#     L2 Error
# 0   0.014186
# 1   0.013711
# 2   0.015265
# 3   0.015199
# 4   0.014528
# 5   0.014546
# 6   0.015208
# 7   0.015246
# 8   0.014601
# 9   0.015091
# 10  0.014758
# Metrics summary saved to /Users/jonathanzha/Desktop/AttenPASOH/results of reviewer/XJTU(GRU) results/1-1/metrics_summary.csv
#       Experiment       MSE       MAE      MAPE      RMSE       R^2  L1 Error  \
# 0    Experiment1  0.007654  0.008226  0.000115  0.010709  0.946926  0.008112
# 1    Experiment2  0.007076  0.007580  0.000099  0.009942  0.954257  0.007500
# 2    Experiment3  0.007220  0.007771  0.000105  0.010268  0.951202  0.007652
# 3    Experiment4  0.006645  0.007136  0.000096  0.009804  0.955512  0.007042
# 4    Experiment5  0.006891  0.007390  0.000099  0.009933  0.954338  0.007303
# 5    Experiment6  0.006596  0.007109  0.000087  0.009322  0.959781  0.006990
# 6    Experiment7  0.006980  0.007504  0.000096  0.009808  0.955482  0.007397
# 7    Experiment8  0.008581  0.009194  0.000137  0.011692  0.936731  0.009094
# 8    Experiment9  0.006865  0.007410  0.000108  0.010398  0.949957  0.007276
# 9   Experiment10  0.006439  0.006948  0.000090  0.009475  0.958446  0.006825
# 10          Mean  0.007095  0.007627  0.000103  0.010135  0.952263  0.007519
#
#     L2 Error
# 0   0.011336
# 1   0.010524
# 2   0.010869
# 3   0.010378
# 4   0.010514
# 5   0.009868
# 6   0.010382
# 7   0.012377
# 8   0.011007
# 9   0.010030
# 10  0.010728
# Metrics summary saved to /Users/jonathanzha/Desktop/AttenPASOH/results of reviewer/XJTU(GRU) results/2-2/metrics_summary.csv
#       Experiment       MSE       MAE      MAPE      RMSE       R^2  L1 Error  \
# 0    Experiment1  0.007965  0.008843  0.000142  0.011937  0.934956  0.008470
# 1    Experiment2  0.006974  0.007732  0.000119  0.010915  0.945614  0.007416
# 2    Experiment3  0.010275  0.011324  0.000192  0.013858  0.912333  0.010926
# 3    Experiment4  0.008237  0.009072  0.000133  0.011545  0.939158  0.008759
# 4    Experiment5  0.008727  0.009614  0.000152  0.012313  0.930789  0.009280
# 5    Experiment6  0.007691  0.008520  0.000137  0.011710  0.937403  0.008178
# 6    Experiment7  0.007578  0.008393  0.000131  0.011446  0.940199  0.008059
# 7    Experiment8  0.009717  0.010736  0.000187  0.013668  0.914723  0.010333
# 8    Experiment9  0.008808  0.009677  0.000149  0.012218  0.931853  0.009366
# 9   Experiment10  0.006915  0.007631  0.000113  0.010630  0.948415  0.007353
# 10          Mean  0.008289  0.009154  0.000146  0.012024  0.933544  0.008814
#
#     L2 Error
# 0   0.012678
# 1   0.011593
# 2   0.014719
# 3   0.012262
# 4   0.013078
# 5   0.012437
# 6   0.012156
# 7   0.014517
# 8   0.012977
# 9   0.011290
# 10  0.012771
# Metrics summary saved to /Users/jonathanzha/Desktop/AttenPASOH/results of reviewer/XJTU(GRU) results/3-3/metrics_summary.csv
#       Experiment       MSE       MAE      MAPE      RMSE       R^2  L1 Error  \
# 0    Experiment1  0.013233  0.014331  0.000315  0.017760  0.707192  0.014088
# 1    Experiment2  0.013988  0.015086  0.000340  0.018426  0.684831  0.014892
# 2    Experiment3  0.012005  0.013040  0.000267  0.016354  0.751708  0.012782
# 3    Experiment4  0.019423  0.020875  0.000576  0.024000  0.465289  0.020679
# 4    Experiment5  0.016084  0.017340  0.000389  0.019725  0.638809  0.017123
# 5    Experiment6  0.010448  0.011402  0.000234  0.015288  0.783023  0.011123
# 6    Experiment7  0.010814  0.011773  0.000247  0.015723  0.770505  0.011513
# 7    Experiment8  0.010298  0.011256  0.000245  0.015644  0.772813  0.010964
# 8    Experiment9  0.012323  0.013368  0.000303  0.017405  0.718790  0.013120
# 9   Experiment10  0.012535  0.013695  0.000346  0.018613  0.678395  0.013346
# 10          Mean  0.013115  0.014217  0.000326  0.017894  0.697135  0.013963
#
#     L2 Error
# 0   0.018897
# 1   0.019605
# 2   0.017401
# 3   0.025536
# 4   0.020988
# 5   0.016267
# 6   0.016729
# 7   0.016645
# 8   0.018519
# 9   0.019804
# 10  0.019039
# Metrics summary saved to /Users/jonathanzha/Desktop/AttenPASOH/results of reviewer/XJTU(GRU) results/4-4/metrics_summary.csv
#       Experiment       MSE       MAE      MAPE      RMSE       R^2  L1 Error  \
# 0    Experiment1  0.007366  0.008005  0.000125  0.011176  0.902932  0.007786
# 1    Experiment2  0.008641  0.009388  0.000157  0.012548  0.877644  0.009134
# 2    Experiment3  0.008265  0.008990  0.000154  0.012392  0.880664  0.008736
# 3    Experiment4  0.007979  0.008673  0.000144  0.011994  0.888207  0.008434
# 4    Experiment5  0.008183  0.008879  0.000139  0.011793  0.891913  0.008650
# 5    Experiment6  0.007859  0.008547  0.000139  0.011792  0.891938  0.008307
# 6    Experiment7  0.007742  0.008436  0.000138  0.011735  0.892976  0.008183
# 7    Experiment8  0.007511  0.008175  0.000132  0.011504  0.897144  0.007939
# 8    Experiment9  0.008373  0.009075  0.000144  0.012016  0.887793  0.008851
# 9   Experiment10  0.007534  0.008164  0.000121  0.011008  0.905825  0.007963
# 10          Mean  0.007945  0.008633  0.000139  0.011796  0.891704  0.008398
#
#     L2 Error
# 0   0.011805
# 1   0.013253
# 2   0.013089
# 3   0.012668
# 4   0.012457
# 5   0.012455
# 6   0.012395
# 7   0.012152
# 8   0.012692
# 9   0.011627
# 10  0.012459
# Metrics summary saved to /Users/jonathanzha/Desktop/AttenPASOH/results of reviewer/XJTU(GRU) results/5-5/metrics_summary.csv
